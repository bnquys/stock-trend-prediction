# %%
from huggingface_hub import login, upload_folder

# (optional) Login with your Hugging Face credentials
login()

# Push your dataset files
upload_folder(
    folder_path="artifacts",
    path_in_repo="",
    repo_id="bnquys/stock-prediction-hyprid", 
    repo_type="dataset"
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/datasets/bnquys/stock-prediction-custom-heheh/commit/3a4058d5974c36053134d92790f8afb08b618d06', commit_message='Upload folder using huggingface_hub', commit_description='', oid='3a4058d5974c36053134d92790f8afb08b618d06', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/bnquys/stock-prediction-custom-heheh', endpoint='https://huggingface.co', repo_type='dataset', repo_id='bnquys/stock-prediction-custom-heheh'), pr_revision=None, pr_num=None)
